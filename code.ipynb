# %% [markdown]
# ## Importing all Necessary Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ind_df.csv", index_col= False)

# %%
df.head()
# Out:
#   North American Industry Classification System (NAICS)      Jan-91  \
# 0                              Retail trade  [44-45]     15,026,890
# 1             Motor vehicle and parts dealers  [441]      3,124,582
# 2                         Automobile dealers  [4411]             ..
# 3                           New car dealers  [44111]      2,563,093
# 4                          Used car dealers  [44112]             ..
#
#        Feb-91      Mar-91      Apr-91      May-91      Jun-91      Jul-91  \
# 0  15,304,585  15,413,591  15,293,409  15,676,083  15,507,931  15,556,313
# 1   3,195,311   3,213,766   3,195,107   3,300,286   3,296,739   3,408,080
# 2          ..          ..          ..          ..          ..          ..
# 3   2,622,090   2,643,380   2,627,159   2,718,565   2,720,551   2,813,519
# 4          ..          ..          ..          ..          ..          ..
#
#        Aug-91      Sep-91  ...       20-Feb       20-Mar       20-Apr  \
# 0  15,430,645  15,427,313  ...  52,262,166A  47,028,013A  35,352,146A
# 1   3,107,689   3,258,453  ...  14,173,381A   8,948,590A   5,137,677A
# 2          ..          ..  ...  12,448,626A   7,482,859A   4,057,963A
# 3   2,555,655   2,683,647  ...  11,388,806A   6,806,280A   3,698,659A
# 4          ..          ..  ...   1,059,819B     676,579B     359,304C
#
#         20-May       20-Jun       20-Jul       20-Aug       20-Sep  \
# 0  42,852,368A  52,371,189A  53,054,315A  53,480,433A  54,435,889A
# 1   9,129,472A  13,527,232A  14,146,172A  14,241,355A  14,485,536A
# 2   7,434,829A  11,408,985A  11,966,427A  12,294,835A  12,509,988A
# 3   6,657,041A  10,427,595A  10,872,602A  11,198,519A  11,405,114A
# 4     777,789C     981,389C   1,093,825B   1,096,316A   1,104,873B
#
#         20-Oct       20-Nov
# 0  54,491,275A  55,193,438A
# 1  14,610,912A  14,476,855A
# 2  12,557,224B  12,423,907B
# 3  11,412,150B  11,299,480B
# 4   1,145,075C   1,124,427D
#
# [5 rows x 360 columns]

# %%
df1 = df.T
df1.head()
# Out:
#                                                                        0   \
# North American Industry Classification System (...  Retail trade  [44-45]
# Jan-91                                                         15,026,890
# Feb-91                                                         15,304,585
# Mar-91                                                         15,413,591
# Apr-91                                                         15,293,409
#
#                                                                                         1   \
# North American Industry Classification System (...  Motor vehicle and parts dealers  [441]
# Jan-91                                                                           3,124,582
# Feb-91                                                                           3,195,311
# Mar-91                                                                           3,213,766
# Apr-91                                                                           3,195,107
#
#                                                                             2   \
# North American Industry Classification System (...  Automobile dealers  [4411]
# Jan-91                                                                      ..
# Feb-91                                                                      ..
# Mar-91                                                                      ..
# Apr-91                                                                      ..
#
#                                                                           3   \
# North American Industry Classification System (...  New car dealers  [44111]
# Jan-91                                                             2,563,093
# Feb-91                                                             2,622,090
# Mar-91                                                             2,643,380
# Apr-91                                                             2,627,159
#
#                                                                            4   \
# North American Industry Classification System (...  Used car dealers  [44112]
# Jan-91                                                                     ..
# Feb-91                                                                     ..
# Mar-91                                                                     ..
# Apr-91                                                                     ..
#
#                                                                                      5   \
# North American Industry Classification System (...  Other motor vehicle dealers  [4412]
# Jan-91                                                                               ..
# Feb-91                                                                               ..
# Mar-91                                                                               ..
# Apr-91                                                                               ..
#
#                                                                                                    6   \
# North American Industry Classification System (...  Automotive parts, accessories and tire stores ...
# Jan-91                                                                                             ..
# Feb-91                                                                                             ..
# Mar-91                                                                                             ..
# Apr-91                                                                                             ..
#
#                                                                                               7   \
# North American Industry Classification System (...  Furniture and home furnishings stores  [442]
# Jan-91                                                                                   468,950
# Feb-91                                                                                   525,639
# Mar-91                                                                                   539,211
# Apr-91                                                                                   541,863
#
#                                                                           8   \
# North American Industry Classification System (...  Furniture stores  [4421]
# Jan-91                                                               314,081
# Feb-91                                                               348,777
# Mar-91                                                               355,802
# Apr-91                                                               361,051
#
#                                                                                  9   \
# North American Industry Classification System (...  Home furnishings stores  [4422]
# Jan-91                                                                      154,869
# Feb-91                                                                      176,862
# Mar-91                                                                      183,409
# Apr-91                                                                      180,812
#
#                                                     ...  \
# North American Industry Classification System (...  ...
# Jan-91                                              ...
# Feb-91                                              ...
# Mar-91                                              ...
# Apr-91                                              ...
#
#                                                                                                  20  \
# North American Industry Classification System (...  Clothing and clothing accessories stores  [448]
# Jan-91                                                                                    1,001,432
# Feb-91                                                                                    1,077,178
# Mar-91                                                                                    1,118,432
# Apr-91                                                                                    1,078,115
#
#                                                                          21  \
# North American Industry Classification System (...  Clothing stores  [4481]
# Jan-91                                                                   ..
# Feb-91                                                                   ..
# Mar-91                                                                   ..
# Apr-91                                                                   ..
#
#                                                                      22  \
# North American Industry Classification System (...  Shoe stores  [4482]
# Jan-91                                                               ..
# Feb-91                                                               ..
# Mar-91                                                               ..
# Apr-91                                                               ..
#
#                                                                                                    23  \
# North American Industry Classification System (...  Jewellery, luggage and leather goods stores  [...
# Jan-91                                                                                             ..
# Feb-91                                                                                             ..
# Mar-91                                                                                             ..
# Apr-91                                                                                             ..
#
#                                                                                                    24  \
# North American Industry Classification System (...  Sporting goods, hobby, book and music stores  ...
# Jan-91                                                                                        414,846
# Feb-91                                                                                        428,124
# Mar-91                                                                                        430,137
# Apr-91                                                                                        424,847
#
#                                                                                    25  \
# North American Industry Classification System (...  General merchandise stores  [452]
# Jan-91                                                                      1,858,426
# Feb-91                                                                      1,899,516
# Mar-91                                                                      1,932,033
# Apr-91                                                                      1,894,595
#
#                                                                            26  \
# North American Industry Classification System (...  Department stores  [4521]
# Jan-91                                                                999,360
# Feb-91                                                              1,007,675
# Mar-91                                                              1,026,369
# Apr-91                                                                973,505
#
#                                                                                           27  \
# North American Industry Classification System (...  Other general merchandise stores  [4529]
# Jan-91                                                                               859,066
# Feb-91                                                                               891,841
# Mar-91                                                                               905,664
# Apr-91                                                                               921,090
#
#                                                                                       28  \
# North American Industry Classification System (...  Miscellaneous store retailers  [453]
# Jan-91                                                                           342,225
# Feb-91                                                                           367,106
# Mar-91                                                                           368,925
# Apr-91                                                                           366,031
#
#                                                                              29
# North American Industry Classification System (...  Cannabis stores  [453993] 6
# Jan-91                                                                       ..
# Feb-91                                                                       ..
# Mar-91                                                                       ..
# Apr-91                                                                       ..
#
# [5 rows x 30 columns]

# %%
df2 = df1.rename({'North American Industry Classification System (NAICS)' : 'Month/Year'})
df2.head()
# Out:
#                                0                                       1   \
# Month/Year  Retail trade  [44-45]  Motor vehicle and parts dealers  [441]
# Jan-91                 15,026,890                               3,124,582
# Feb-91                 15,304,585                               3,195,311
# Mar-91                 15,413,591                               3,213,766
# Apr-91                 15,293,409                               3,195,107
#
#                                     2                         3   \
# Month/Year  Automobile dealers  [4411]  New car dealers  [44111]
# Jan-91                              ..                 2,563,093
# Feb-91                              ..                 2,622,090
# Mar-91                              ..                 2,643,380
# Apr-91                              ..                 2,627,159
#
#                                    4                                    5   \
# Month/Year  Used car dealers  [44112]  Other motor vehicle dealers  [4412]
# Jan-91                             ..                                   ..
# Feb-91                             ..                                   ..
# Mar-91                             ..                                   ..
# Apr-91                             ..                                   ..
#
#                                                            6   \
# Month/Year  Automotive parts, accessories and tire stores ...
# Jan-91                                                     ..
# Feb-91                                                     ..
# Mar-91                                                     ..
# Apr-91                                                     ..
#
#                                                       7   \
# Month/Year  Furniture and home furnishings stores  [442]
# Jan-91                                           468,950
# Feb-91                                           525,639
# Mar-91                                           539,211
# Apr-91                                           541,863
#
#                                   8                                9   ...  \
# Month/Year  Furniture stores  [4421]  Home furnishings stores  [4422]  ...
# Jan-91                       314,081                          154,869  ...
# Feb-91                       348,777                          176,862  ...
# Mar-91                       355,802                          183,409  ...
# Apr-91                       361,051                          180,812  ...
#
#                                                          20  \
# Month/Year  Clothing and clothing accessories stores  [448]
# Jan-91                                            1,001,432
# Feb-91                                            1,077,178
# Mar-91                                            1,118,432
# Apr-91                                            1,078,115
#
#                                  21                   22  \
# Month/Year  Clothing stores  [4481]  Shoe stores  [4482]
# Jan-91                           ..                   ..
# Feb-91                           ..                   ..
# Mar-91                           ..                   ..
# Apr-91                           ..                   ..
#
#                                                            23  \
# Month/Year  Jewellery, luggage and leather goods stores  [...
# Jan-91                                                     ..
# Feb-91                                                     ..
# Mar-91                                                     ..
# Apr-91                                                     ..
#
#                                                            24  \
# Month/Year  Sporting goods, hobby, book and music stores  ...
# Jan-91                                                414,846
# Feb-91                                                428,124
# Mar-91                                                430,137
# Apr-91                                                424,847
#
#                                            25                         26  \
# Month/Year  General merchandise stores  [452]  Department stores  [4521]
# Jan-91                              1,858,426                    999,360
# Feb-91                              1,899,516                  1,007,675
# Mar-91                              1,932,033                  1,026,369
# Apr-91                              1,894,595                    973,505
#
#                                                   27  \
# Month/Year  Other general merchandise stores  [4529]
# Jan-91                                       859,066
# Feb-91                                       891,841
# Mar-91                                       905,664
# Apr-91                                       921,090
#
#                                               28                           29
# Month/Year  Miscellaneous store retailers  [453]  Cannabis stores  [453993] 6
# Jan-91                                   342,225                           ..
# Feb-91                                   367,106                           ..
# Mar-91                                   368,925                           ..
# Apr-91                                   366,031                           ..
#
# [5 rows x 30 columns]

# %%
df2.to_csv('fdf1.csv')

# %%
dff = pd.read_csv('fdf1.csv', header = 1)
dff.head()
# Out:
#   Month/Year Retail trade  [44-45] Motor vehicle and parts dealers  [441]  \
# 0     Jan-91            15,026,890                              3,124,582
# 1     Feb-91            15,304,585                              3,195,311
# 2     Mar-91            15,413,591                              3,213,766
# 3     Apr-91            15,293,409                              3,195,107
# 4     May-91            15,676,083                              3,300,286
#
#   Automobile dealers  [4411] New car dealers  [44111]  \
# 0                         ..                2,563,093
# 1                         ..                2,622,090
# 2                         ..                2,643,380
# 3                         ..                2,627,159
# 4                         ..                2,718,565
#
#   Used car dealers  [44112] Other motor vehicle dealers  [4412]  \
# 0                        ..                                  ..
# 1                        ..                                  ..
# 2                        ..                                  ..
# 3                        ..                                  ..
# 4                        ..                                  ..
#
#   Automotive parts, accessories and tire stores  [4413]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Furniture and home furnishings stores  [442] Furniture stores  [4421]  ...  \
# 0                                      468,950                  314,081  ...
# 1                                      525,639                  348,777  ...
# 2                                      539,211                  355,802  ...
# 3                                      541,863                  361,051  ...
# 4                                      553,422                  370,270  ...
#
#   Clothing and clothing accessories stores  [448] Clothing stores  [4481]  \
# 0                                       1,001,432                      ..
# 1                                       1,077,178                      ..
# 2                                       1,118,432                      ..
# 3                                       1,078,115                      ..
# 4                                       1,083,460                      ..
#
#   Shoe stores  [4482] Jewellery, luggage and leather goods stores  [4483]  \
# 0                  ..                                                 ..
# 1                  ..                                                 ..
# 2                  ..                                                 ..
# 3                  ..                                                 ..
# 4                  ..                                                 ..
#
#   Sporting goods, hobby, book and music stores  [451]  \
# 0                                            414,846
# 1                                            428,124
# 2                                            430,137
# 3                                            424,847
# 4                                            440,970
#
#   General merchandise stores  [452] Department stores  [4521]  \
# 0                         1,858,426                   999,360
# 1                         1,899,516                 1,007,675
# 2                         1,932,033                 1,026,369
# 3                         1,894,595                   973,505
# 4                         1,987,917                 1,024,999
#
#   Other general merchandise stores  [4529]  \
# 0                                  859,066
# 1                                  891,841
# 2                                  905,664
# 3                                  921,090
# 4                                  962,918
#
#   Miscellaneous store retailers  [453] Cannabis stores  [453993] 6
# 0                              342,225                          ..
# 1                              367,106                          ..
# 2                              368,925                          ..
# 3                              366,031                          ..
# 4                              365,133                          ..
#
# [5 rows x 31 columns]

# %%
n_cols = ['Month/Year', 'Retail trade', 'Motor vehicle and parts dealers', 'Automobile dealers', 'New car dealers', 'Used car dealers', 'Other motor vehicle dealers', 'Automotive parts - accessories and tire stores', 'Furniture and home furnishings stores', 'Furniture stores', 'Home furnishings stores', 'Electronics and appliance stores', 'Building material and garden equipment and supplies dealers', 'Food and beverage stores', 'Grocery stores', 'Supermarkets and other grocery (except convenience) stores', 'Convenience stores', 'Specialty food stores', 'Beer, wine and liquor stores', 'Health and personal care stores', 'Gasoline stations', 'Clothing and clothing accessories stores', 'Clothing stores', 'Shoe stores', 'Jewellery/luggage and leather goods stores', 'Sporting goods, hobby, book and music stores', 'General merchandise stores', 'Department stores', 'Other general merchandise stores', 'Miscellaneous store retailers', 'Cannabis stores']

# %%
dff.columns = n_cols

# %%
dff.head()
# Out:
#   Month/Year Retail trade Motor vehicle and parts dealers Automobile dealers  \
# 0     Jan-91   15,026,890                       3,124,582                 ..
# 1     Feb-91   15,304,585                       3,195,311                 ..
# 2     Mar-91   15,413,591                       3,213,766                 ..
# 3     Apr-91   15,293,409                       3,195,107                 ..
# 4     May-91   15,676,083                       3,300,286                 ..
#
#   New car dealers Used car dealers Other motor vehicle dealers  \
# 0       2,563,093               ..                          ..
# 1       2,622,090               ..                          ..
# 2       2,643,380               ..                          ..
# 3       2,627,159               ..                          ..
# 4       2,718,565               ..                          ..
#
#   Automotive parts - accessories and tire stores  \
# 0                                             ..
# 1                                             ..
# 2                                             ..
# 3                                             ..
# 4                                             ..
#
#   Furniture and home furnishings stores Furniture stores  ...  \
# 0                               468,950          314,081  ...
# 1                               525,639          348,777  ...
# 2                               539,211          355,802  ...
# 3                               541,863          361,051  ...
# 4                               553,422          370,270  ...
#
#   Clothing and clothing accessories stores Clothing stores Shoe stores  \
# 0                                1,001,432              ..          ..
# 1                                1,077,178              ..          ..
# 2                                1,118,432              ..          ..
# 3                                1,078,115              ..          ..
# 4                                1,083,460              ..          ..
#
#   Jewellery/luggage and leather goods stores  \
# 0                                         ..
# 1                                         ..
# 2                                         ..
# 3                                         ..
# 4                                         ..
#
#   Sporting goods, hobby, book and music stores General merchandise stores  \
# 0                                      414,846                  1,858,426
# 1                                      428,124                  1,899,516
# 2                                      430,137                  1,932,033
# 3                                      424,847                  1,894,595
# 4                                      440,970                  1,987,917
#
#   Department stores Other general merchandise stores  \
# 0           999,360                          859,066
# 1         1,007,675                          891,841
# 2         1,026,369                          905,664
# 3           973,505                          921,090
# 4         1,024,999                          962,918
#
#   Miscellaneous store retailers Cannabis stores
# 0                       342,225              ..
# 1                       367,106              ..
# 2                       368,925              ..
# 3                       366,031              ..
# 4                       365,133              ..
#
# [5 rows x 31 columns]

# %%
dff.to_csv('fdf2.csv')

# %%
dff1 = pd.read_csv('fdf2.csv', index_col = 0)
dff1.head()
# Out:
#   Month/Year Retail trade Motor vehicle and parts dealers Automobile dealers  \
# 0     Jan-91   15,026,890                       3,124,582                 ..
# 1     Feb-91   15,304,585                       3,195,311                 ..
# 2     Mar-91   15,413,591                       3,213,766                 ..
# 3     Apr-91   15,293,409                       3,195,107                 ..
# 4     May-91   15,676,083                       3,300,286                 ..
#
#   New car dealers Used car dealers Other motor vehicle dealers  \
# 0       2,563,093               ..                          ..
# 1       2,622,090               ..                          ..
# 2       2,643,380               ..                          ..
# 3       2,627,159               ..                          ..
# 4       2,718,565               ..                          ..
#
#   Automotive parts - accessories and tire stores  \
# 0                                             ..
# 1                                             ..
# 2                                             ..
# 3                                             ..
# 4                                             ..
#
#   Furniture and home furnishings stores Furniture stores  ...  \
# 0                               468,950          314,081  ...
# 1                               525,639          348,777  ...
# 2                               539,211          355,802  ...
# 3                               541,863          361,051  ...
# 4                               553,422          370,270  ...
#
#   Clothing and clothing accessories stores Clothing stores Shoe stores  \
# 0                                1,001,432              ..          ..
# 1                                1,077,178              ..          ..
# 2                                1,118,432              ..          ..
# 3                                1,078,115              ..          ..
# 4                                1,083,460              ..          ..
#
#   Jewellery/luggage and leather goods stores  \
# 0                                         ..
# 1                                         ..
# 2                                         ..
# 3                                         ..
# 4                                         ..
#
#   Sporting goods, hobby, book and music stores General merchandise stores  \
# 0                                      414,846                  1,858,426
# 1                                      428,124                  1,899,516
# 2                                      430,137                  1,932,033
# 3                                      424,847                  1,894,595
# 4                                      440,970                  1,987,917
#
#   Department stores Other general merchandise stores  \
# 0           999,360                          859,066
# 1         1,007,675                          891,841
# 2         1,026,369                          905,664
# 3           973,505                          921,090
# 4         1,024,999                          962,918
#
#   Miscellaneous store retailers Cannabis stores
# 0                       342,225              ..
# 1                       367,106              ..
# 2                       368,925              ..
# 3                       366,031              ..
# 4                       365,133              ..
#
# [5 rows x 31 columns]

# %%
dff2 = dff1.replace('\.+', np.nan, regex=True)
dff2.head()
# Out:
#   Month/Year Retail trade Motor vehicle and parts dealers Automobile dealers  \
# 0     Jan-91   15,026,890                       3,124,582                NaN
# 1     Feb-91   15,304,585                       3,195,311                NaN
# 2     Mar-91   15,413,591                       3,213,766                NaN
# 3     Apr-91   15,293,409                       3,195,107                NaN
# 4     May-91   15,676,083                       3,300,286                NaN
#
#   New car dealers Used car dealers Other motor vehicle dealers  \
# 0       2,563,093              NaN                         NaN
# 1       2,622,090              NaN                         NaN
# 2       2,643,380              NaN                         NaN
# 3       2,627,159              NaN                         NaN
# 4       2,718,565              NaN                         NaN
#
#   Automotive parts - accessories and tire stores  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Furniture and home furnishings stores Furniture stores  ...  \
# 0                               468,950          314,081  ...
# 1                               525,639          348,777  ...
# 2                               539,211          355,802  ...
# 3                               541,863          361,051  ...
# 4                               553,422          370,270  ...
#
#   Clothing and clothing accessories stores Clothing stores Shoe stores  \
# 0                                1,001,432             NaN         NaN
# 1                                1,077,178             NaN         NaN
# 2                                1,118,432             NaN         NaN
# 3                                1,078,115             NaN         NaN
# 4                                1,083,460             NaN         NaN
#
#   Jewellery/luggage and leather goods stores  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Sporting goods, hobby, book and music stores General merchandise stores  \
# 0                                      414,846                  1,858,426
# 1                                      428,124                  1,899,516
# 2                                      430,137                  1,932,033
# 3                                      424,847                  1,894,595
# 4                                      440,970                  1,987,917
#
#   Department stores Other general merchandise stores  \
# 0           999,360                          859,066
# 1         1,007,675                          891,841
# 2         1,026,369                          905,664
# 3           973,505                          921,090
# 4         1,024,999                          962,918
#
#   Miscellaneous store retailers Cannabis stores
# 0                       342,225             NaN
# 1                       367,106             NaN
# 2                       368,925             NaN
# 3                       366,031             NaN
# 4                       365,133             NaN
#
# [5 rows x 31 columns]

# %%
nas = dff2.isnull().sum()
nas
# Out:
# Month/Year                                                       0
# Retail trade                                                     0
# Motor vehicle and parts dealers                                  0
# Automobile dealers                                             156
# New car dealers                                                  0
# Used car dealers                                               156
# Other motor vehicle dealers                                    156
# Automotive parts - accessories and tire stores                 156
# Furniture and home furnishings stores                            0
# Furniture stores                                                 0
# Home furnishings stores                                          0
# Electronics and appliance stores                                 0
# Building material and garden equipment and supplies dealers      0
# Food and beverage stores                                         0
# Grocery stores                                                 156
# Supermarkets and other grocery (except convenience) stores       0
# Convenience stores                                             156
# Specialty food stores                                          156
# Beer, wine and liquor stores                                     0
# Health and personal care stores                                  0
# Gasoline stations                                                0
# Clothing and clothing accessories stores                         0
# Clothing stores                                                156
# Shoe stores                                                    156
# Jewellery/luggage and leather goods stores                     156
# Sporting goods, hobby, book and music stores                     0
# General merchandise stores                                       0
# Department stores                                                0
# Other general merchandise stores                                 0
# Miscellaneous store retailers                                    0
# Cannabis stores                                                333
# dtype: int64

# %%
dff2.describe().transpose()
# Out:
#        Month/Year Retail trade Motor vehicle and parts dealers  \
# count         359          359                             359
# unique        359          359                             359
# top        19-Apr  40,890,989A                       4,137,403
# freq            1            1                               1
#
#        Automobile dealers New car dealers Used car dealers  \
# count                 203             359              203
# unique                203             359              203
# top            6,713,812A      5,985,891A         592,242C
# freq                    1               1                1
#
#        Other motor vehicle dealers  \
# count                          203
# unique                         203
# top                       577,882B
# freq                             1
#
#        Automotive parts - accessories and tire stores  \
# count                                             203
# unique                                            202
# top                                          588,162A
# freq                                                2
#
#        Furniture and home furnishings stores Furniture stores  ...  \
# count                                    359              359  ...
# unique                                   359              359  ...
# top                                  799,521         958,982A  ...
# freq                                       1                1  ...
#
#        Clothing and clothing accessories stores Clothing stores Shoe stores  \
# count                                       359             203         203
# unique                                      359             203         203
# top                                   1,471,927      1,678,884A    238,870A
# freq                                          1               1           1
#
#        Jewellery/luggage and leather goods stores  \
# count                                         203
# unique                                        203
# top                                      232,132A
# freq                                            1
#
#        Sporting goods, hobby, book and music stores  \
# count                                           359
# unique                                          359
# top                                        717,965A
# freq                                              1
#
#        General merchandise stores Department stores  \
# count                         359               359
# unique                        359               208
# top                    4,757,343A                 x
# freq                            1               152
#
#        Other general merchandise stores Miscellaneous store retailers  \
# count                               359                           359
# unique                              208                           359
# top                                   x                       621,571
# freq                                152                             1
#
#        Cannabis stores
# count               26
# unique              26
# top           125,954A
# freq                 1
#
# [4 rows x 31 columns]

# %%
dff2.shape
# Out:
# (359, 31)

# %%
import seaborn as sns
from matplotlib import rcParams
rcParams['figure.figsize'] = 20,5
sns.heatmap(dff2.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
dff3 = dff2.replace(np.nan, 0)
dff3.head()
# Out:
#   Month/Year Retail trade Motor vehicle and parts dealers Automobile dealers  \
# 0     Jan-91   15,026,890                       3,124,582                  0
# 1     Feb-91   15,304,585                       3,195,311                  0
# 2     Mar-91   15,413,591                       3,213,766                  0
# 3     Apr-91   15,293,409                       3,195,107                  0
# 4     May-91   15,676,083                       3,300,286                  0
#
#   New car dealers Used car dealers Other motor vehicle dealers  \
# 0       2,563,093                0                           0
# 1       2,622,090                0                           0
# 2       2,643,380                0                           0
# 3       2,627,159                0                           0
# 4       2,718,565                0                           0
#
#   Automotive parts - accessories and tire stores  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#   Furniture and home furnishings stores Furniture stores  ...  \
# 0                               468,950          314,081  ...
# 1                               525,639          348,777  ...
# 2                               539,211          355,802  ...
# 3                               541,863          361,051  ...
# 4                               553,422          370,270  ...
#
#   Clothing and clothing accessories stores Clothing stores Shoe stores  \
# 0                                1,001,432               0           0
# 1                                1,077,178               0           0
# 2                                1,118,432               0           0
# 3                                1,078,115               0           0
# 4                                1,083,460               0           0
#
#   Jewellery/luggage and leather goods stores  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
#
#   Sporting goods, hobby, book and music stores General merchandise stores  \
# 0                                      414,846                  1,858,426
# 1                                      428,124                  1,899,516
# 2                                      430,137                  1,932,033
# 3                                      424,847                  1,894,595
# 4                                      440,970                  1,987,917
#
#   Department stores Other general merchandise stores  \
# 0           999,360                          859,066
# 1         1,007,675                          891,841
# 2         1,026,369                          905,664
# 3           973,505                          921,090
# 4         1,024,999                          962,918
#
#   Miscellaneous store retailers Cannabis stores
# 0                       342,225               0
# 1                       367,106               0
# 2                       368,925               0
# 3                       366,031               0
# 4                       365,133               0
#
# [5 rows x 31 columns]

# %%
dff3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359 entries, 0 to 358
# Data columns (total 31 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Month/Year                                                   359 non-null    object
#  1   Retail trade                                                 359 non-null    object
#  2   Motor vehicle and parts dealers                              359 non-null    object
#  3   Automobile dealers                                           359 non-null    object
#  4   New car dealers                                              359 non-null    object
#  5   Used car dealers                                             359 non-null    object
#  6   Other motor vehicle dealers                                  359 non-null    object
#  7   Automotive parts - accessories and tire stores               359 non-null    object
#  8   Furniture and home furnishings stores                        359 non-null    object
#  9   Furniture stores                                             359 non-null    object
#  10  Home furnishings stores                                      359 non-null    object
#  11  Electronics and appliance stores                             359 non-null    object
#  12  Building material and garden equipment and supplies dealers  359 non-null    object
#  13  Food and beverage stores                                     359 non-null    object
#  14  Grocery stores                                               359 non-null    object
#  15  Supermarkets and other grocery (except convenience) stores   359 non-null    object
#  16  Convenience stores                                           359 non-null    object
#  17  Specialty food stores                                        359 non-null    object
#  18  Beer, wine and liquor stores                                 359 non-null    object
#  19  Health and personal care stores                              359 non-null    object
#  20  Gasoline stations                                            359 non-null    object
#  21  Clothing and clothing accessories stores                     359 non-null    object
#  22  Clothing stores                                              359 non-null    object
#  23  Shoe stores                                                  359 non-null    object
#  24  Jewellery/luggage and leather goods stores                   359 non-null    object
#  25  Sporting goods, hobby, book and music stores                 359 non-null    object
#  26  General merchandise stores                                   359 non-null    object
#  27  Department stores                                            359 non-null    object
#  28  Other general merchandise stores                             359 non-null    object
#  29  Miscellaneous store retailers                                359 non-null    object
#  30  Cannabis stores                                              359 non-null    object
# dtypes: object(31)
# memory usage: 89.8+ KB

# %%
## dff2 = pd.to_numeric(dff2['Grocery stores'])
dff3 = dff3['Grocery stores'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-1b025a1b0541> in <module>
#       1 ## dff2 = pd.to_numeric(dff2['Grocery stores'])
# ----> 2 dff3 = dff3['Grocery stores'].astype('int64')
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5872         else:
#    5873             # else, only a single dtype is given
# -> 5874             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5875             return self._constructor(new_data).__finalize__(self, method="astype")
#    5876
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1072         # work around NumPy brokenness, #1987
#    1073         if np.issubdtype(dtype.type, np.integer):
# -> 1074             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#    1075
#    1076         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '5,451,108A'

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x='Month/Year', y='Grocery stores', data = dff3, palette='winter')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-b35063839541> in <module>
#       1 plt.figure(figsize=(12,7))
# ----> 2 sns.boxplot(x='Month/Year', y='Grocery stores', data = dff3, palette='winter')
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2238 ):
#    2239
# -> 2240     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2241                           orient, color, palette, saturation,
#    2242                           width, dodge, fliersize, linewidth)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     404                  width, dodge, fliersize, linewidth):
#     405
# --> 406         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     407         self.establish_colors(color, palette, saturation)
#     408
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     154
#     155             # Figure out the plotting orientation
# --> 156             orient = infer_orient(
#     157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\_core.py in infer_orient(x, y, orient, require_numeric)
#    1343     elif require_numeric and "numeric" not in (x_type, y_type):
#    1344         err = "Neither the `x` nor `y` variable appears to be numeric."
# -> 1345         raise TypeError(err)
#    1346
#    1347     else:
#
# TypeError: Neither the `x` nor `y` variable appears to be numeric.
